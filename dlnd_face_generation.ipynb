# %% [markdown]
# # Face Generation
# In this project, you'll use generative adversarial networks to generate new images of faces.
# ### Get the Data
# You'll be using two datasets in this project:
# - MNIST
# - CelebA
#
# Since the celebA dataset is complex and you're doing GANs in a project for the first time, we want you to test your neural network on MNIST before CelebA.  Running the GANs on MNIST will allow you to see how well your model trains sooner.
#
# If you're using [FloydHub](https://www.floydhub.com/), set `data_dir` to "/input" and use the [FloydHub data ID](http://docs.floydhub.com/home/using_datasets/) "R5KrjnANiKVhLWAkpXhNBe".

# %%
data_dir = './data'

# FloydHub - Use with data ID "R5KrjnANiKVhLWAkpXhNBe"
#data_dir = '/input'


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper

helper.download_extract('mnist', data_dir)
helper.download_extract('celeba', data_dir)
# Out:
# Found mnist Data
# Found celeba Data

# %% [markdown]
# ## Explore the Data
# ### MNIST
# As you're aware, the [MNIST](http://yann.lecun.com/exdb/mnist/) dataset contains images of handwritten digits. You can view the first number of examples by changing `show_n_images`.

# %%
show_n_images = 25

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
import os
from glob import glob
from matplotlib import pyplot

mnist_images = helper.get_batch(glob(os.path.join(data_dir, 'mnist/*.jpg'))[:show_n_images], 28, 28, 'L')
pyplot.imshow(helper.images_square_grid(mnist_images, 'L'), cmap='gray')

# %% [markdown]
# ### CelebA
# The [CelebFaces Attributes Dataset (CelebA)](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) dataset contains over 200,000 celebrity images with annotations.  Since you're going to be generating faces, you won't need the annotations.  You can view the first number of examples by changing `show_n_images`.

# %%
show_n_images = 25

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
mnist_images = helper.get_batch(glob(os.path.join(data_dir, 'img_align_celeba/*.jpg'))[:show_n_images], 28, 28, 'RGB')
pyplot.imshow(helper.images_square_grid(mnist_images, 'RGB'))

# %% [markdown]
# ## Preprocess the Data
# Since the project's main focus is on building the GANs, we'll preprocess the data for you.  The values of the MNIST and CelebA dataset will be in the range of -0.5 to 0.5 of 28x28 dimensional images.  The CelebA images will be cropped to remove parts of the image that don't include a face, then resized down to 28x28.
#
# The MNIST images are black and white images with a single [color channel](https://en.wikipedia.org/wiki/Channel_(digital_image%29) while the CelebA images have [3 color channels (RGB color channel)](https://en.wikipedia.org/wiki/Channel_(digital_image%29#RGB_Images).
# ## Build the Neural Network
# You'll build the components necessary to build a GANs by implementing the following functions below:
# - `model_inputs`
# - `discriminator`
# - `generator`
# - `model_loss`
# - `model_opt`
# - `train`
#
# ### Check the Version of TensorFlow and Access to GPU
# This will check to make sure you have the correct version of TensorFlow and access to a GPU

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf

# Check TensorFlow Version
assert LooseVersion(tf.__version__) >= LooseVersion('1.0'), 'Please use TensorFlow version 1.0 or newer.  You are using {}'.format(tf.__version__)
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.0.0
# Default GPU Device: /gpu:0

# %% [markdown]
# ### Input
# Implement the `model_inputs` function to create TF Placeholders for the Neural Network. It should create the following placeholders:
# - Real input images placeholder with rank 4 using `image_width`, `image_height`, and `image_channels`.
# - Z input placeholder with rank 2 using `z_dim`.
# - Learning rate placeholder with rank 0.
#
# Return the placeholders in the following the tuple (tensor of real input images, tensor of z data)

# %%
import problem_unittests as tests

def model_inputs(image_width, image_height, image_channels, z_dim):
    """
    Create the model inputs
    :param image_width: The input image width
    :param image_height: The input image height
    :param image_channels: The number of image channels
    :param z_dim: The dimension of Z
    :return: Tuple of (tensor of real input images, tensor of z data, learning rate)
    """
    # TODO: Implement Function
    real_inputs = tf.placeholder(tf.float32,(None,image_width,image_height,image_channels),name="real_inputs")
    z_inputs = tf.placeholder(tf.float32,(None,z_dim),name="z_inputs")
    learning_rate = tf.placeholder(tf.float32,name="lean_rate")
    
    return real_inputs, z_inputs, learning_rate


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### Discriminator
# Implement `discriminator` to create a discriminator neural network that discriminates on `images`.  This function should be able to reuse the variables in the neural network.  Use [`tf.variable_scope`](https://www.tensorflow.org/api_docs/python/tf/variable_scope) with a scope name of "discriminator" to allow the variables to be reused.  The function should return a tuple of (tensor output of the discriminator, tensor logits of the discriminator).

# %%
def discriminator(images, reuse=False):
    """
    Create the discriminator network
    :param images: Tensor of input image(s)
    :param reuse: Boolean if the weights should be reused
    :return: Tuple of (tensor output of the discriminator, tensor logits of the discriminator)
    """
    # TODO: Implement Function
    alpha = 0.2
    with tf.variable_scope("discriminator",reuse=reuse):
        
        #input 28x28x3
        x = tf.layers.conv2d(images,64,5,strides=2,padding="same",activation=None)
        x = tf.maximum(x * alpha,x)
        #now 14x14x64
        
        x2 = tf.layers.conv2d(x,128,5,strides=2,padding="same",activation=None,use_bias=False)
        x2 = tf.layers.batch_normalization(x2,training=True)
        x2 = tf.maximum(x2 * alpha,x2)
        #now 7x7x128
        
        x3 = tf.layers.conv2d(x2,256,5,strides=2,padding="same",activation=None,use_bias=False)
        x3 = tf.layers.batch_normalization(x3,training=True)
        x3 = tf.maximum(x3 * alpha,x3)
        #now 4x4x256
        
        flat = tf.reshape(x3,(-1,4*4*256))
        logits = tf.layers.dense(flat,1,activation=None)
        output = tf.sigmoid(logits)

        
    return output, logits


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_discriminator(discriminator, tf)
# Out:
# Tests Passed

# %% [markdown]
# ### Generator
# Implement `generator` to generate an image using `z`. This function should be able to reuse the variables in the neural network.  Use [`tf.variable_scope`](https://www.tensorflow.org/api_docs/python/tf/variable_scope) with a scope name of "generator" to allow the variables to be reused. The function should return the generated 28 x 28 x `out_channel_dim` images.

# %%
def generator(z, out_channel_dim, is_train=True):
    """
    Create the generator network
    :param z: Input z
    :param out_channel_dim: The number of channels in the output image
    :param is_train: Boolean if generator is being used for training
    :return: The tensor output of the generator
    """
    # TODO: Implement Function
    alpha = 0.2
    with tf.variable_scope("generator",reuse=not is_train):
        
        #First layer
        x = tf.layers.dense(z,7*7*512,kernel_initializer=tf.contrib.layers.xavier_initializer(uniform=True, dtype=tf.float32))
        
        x = tf.reshape(x,(-1,7,7,512))
        x = tf.layers.batch_normalization(x,training=is_train)
        x = tf.maximum(x*alpha,x)
        #7x7x512
        
        x2 = tf.layers.conv2d_transpose(x,256,5,strides=2,padding="same",activation=None,use_bias=False)
        x2 = tf.layers.batch_normalization(x2,training=is_train)
        x2 = tf.maximum(x2 * alpha,x2)
        #14x14x256
        
        x3 = tf.layers.conv2d_transpose(x2,128,5,strides=2,padding="same",activation=None,use_bias=False)
        x3 = tf.layers.batch_normalization(x3,training=is_train)
        x3 = tf.maximum(x3 * alpha,x3)
        #28x28x128
        
        logits = tf.layers.conv2d_transpose(x3,out_channel_dim,5,strides=1,padding="same", activation=None)
        output = tf.tanh(logits)
        
    return output


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_generator(generator, tf)
# Out:
# Tests Passed

# %% [markdown]
# ### Loss
# Implement `model_loss` to build the GANs for training and calculate the loss.  The function should return a tuple of (discriminator loss, generator loss).  Use the following functions you implemented:
# - `discriminator(images, reuse=False)`
# - `generator(z, out_channel_dim, is_train=True)`

# %%
def model_loss(input_real, input_z, out_channel_dim):
    """
    Get the loss for the discriminator and generator
    :param input_real: Images from the real dataset
    :param input_z: Z input
    :param out_channel_dim: The number of channels in the output image
    :return: A tuple of (discriminator loss, generator loss)
    """
    # TODO: Implement Function
    
    model_generator = generator(input_z, out_channel_dim, is_train=True)
    d_model_real, d_logits_real = discriminator(input_real, reuse=False)
    d_model_fake, d_logits_fake = discriminator(model_generator,reuse=True)
    
    smooth = 0.1
    
    labels_fake = tf.zeros_like(d_logits_real)
    labels_real = tf.ones_like(d_logits_real) * (1 - smooth)
    labels_generator = tf.ones_like(d_logits_fake)
    
    d_fake_loss = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_fake, 
                                                                         labels=labels_fake))
    
    d_real_loss = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_real, 
                                                                         labels=labels_real))
    
    d_loss = d_fake_loss + d_real_loss
    
    g_loss = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_fake, 
                                                                         labels=labels_generator))
    
    
    return d_loss, g_loss


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_loss(model_loss)
# Out:
# Tests Passed

# %% [markdown]
# ### Optimization
# Implement `model_opt` to create the optimization operations for the GANs. Use [`tf.trainable_variables`](https://www.tensorflow.org/api_docs/python/tf/trainable_variables) to get all the trainable variables.  Filter the variables with names that are in the discriminator and generator scope names.  The function should return a tuple of (discriminator training operation, generator training operation).

# %%
def model_opt(d_loss, g_loss, learning_rate, beta1):
    """
    Get optimization operations
    :param d_loss: Discriminator loss Tensor
    :param g_loss: Generator loss Tensor
    :param learning_rate: Learning Rate Placeholder
    :param beta1: The exponential decay rate for the 1st moment in the optimizer
    :return: A tuple of (discriminator training operation, generator training operation)
    """
    # TODO: Implement Function
    
    t_vars = tf.trainable_variables()
    d_train_vars = [var for var in t_vars if var.name.startswith('discriminator')]
    g_train_vars = [var for var in t_vars if var.name.startswith('generator')]
    
    with tf.control_dependencies(tf.get_collection(tf.GraphKeys.UPDATE_OPS)):
        d_opt = tf.train.AdamOptimizer(learning_rate,beta1=beta1).minimize(d_loss,var_list=d_train_vars)
        g_opt = tf.train.AdamOptimizer(learning_rate,beta1=beta1).minimize(g_loss,var_list=g_train_vars)
    
    return d_opt, g_opt


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_opt(model_opt, tf)
# Out:
# Tests Passed

# %% [markdown]
# ## Neural Network Training
# ### Show Output
# Use this function to show the current output of the generator during training. It will help you determine how well the GANs is training.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

def show_generator_output(sess, n_images, input_z, out_channel_dim, image_mode):
    """
    Show example output for the generator
    :param sess: TensorFlow session
    :param n_images: Number of Images to display
    :param input_z: Input Z Tensor
    :param out_channel_dim: The number of channels in the output image
    :param image_mode: The mode to use for images ("RGB" or "L")
    """
    cmap = None if image_mode == 'RGB' else 'gray'
    z_dim = input_z.get_shape().as_list()[-1]
    example_z = np.random.uniform(-1, 1, size=[n_images, z_dim])

    samples = sess.run(
        generator(input_z, out_channel_dim, False),
        feed_dict={input_z: example_z})

    images_grid = helper.images_square_grid(samples, image_mode)
    pyplot.imshow(images_grid, cmap=cmap)
    pyplot.show()

# %% [markdown]
# ### Train
# Implement `train` to build and train the GANs.  Use the following functions you implemented:
# - `model_inputs(image_width, image_height, image_channels, z_dim)`
# - `model_loss(input_real, input_z, out_channel_dim)`
# - `model_opt(d_loss, g_loss, learning_rate, beta1)`
#
# Use the `show_generator_output` to show `generator` output while you train. Running `show_generator_output` for every batch will drastically increase training time and increase the size of the notebook.  It's recommended to print the `generator` output every 100 batches.

# %%
def train(epoch_count, batch_size, z_dim, learning_rate_dec, beta1, get_batches, data_shape, data_image_mode):
    """
    Train the GAN
    :param epoch_count: Number of epochs
    :param batch_size: Batch Size
    :param z_dim: Z dimension
    :param learning_rate: Learning Rate
    :param beta1: The exponential decay rate for the 1st moment in the optimizer
    :param get_batches: Function to get batches
    :param data_shape: Shape of the data
    :param data_image_mode: The image mode to use for images ("RGB" or "L")
    """
    # TODO: Build Model
    steps = 0
    print_every = 20
    show_every = 100
    
    img_channels = 1 if data_image_mode == "L" else 3
    img_w = data_shape[1]
    img_h = data_shape[1]
    real_inputs, z_inputs, learning_rate = model_inputs(z_dim=z_dim,
                                                        image_channels=img_channels,
                                                        image_height=img_h,
                                                        image_width=img_w)
    
    d_loss, g_loss = model_loss(out_channel_dim=img_channels,input_real=real_inputs,input_z=z_inputs)
    d_opt, g_opt = model_opt(d_loss,g_loss,learning_rate,beta1)
    
    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        for epoch_i in range(epoch_count):
            for batch_images in get_batches(batch_size):
                # TODO: Train Model
                steps += 1
                batch_z = np.random.uniform(-1, 1, size=(batch_size, z_dim))
                batch_images = batch_images*2 
                ## run optimzer
                _ = sess.run(d_opt,feed_dict={real_inputs:batch_images,z_inputs:batch_z,learning_rate:learning_rate_dec})
                _ = sess.run(g_opt,feed_dict={real_inputs:batch_images,z_inputs:batch_z,learning_rate:learning_rate_dec})

                if steps % print_every == 0:
                    # At the end of each epoch, get the losses and print them out
                    train_loss_d = d_loss.eval({real_inputs:batch_images, z_inputs: batch_z})
                    train_loss_g = g_loss.eval({z_inputs: batch_z})

                    print("Epoch {}/{}...".format(epoch_i+1, epochs),
                          "Discriminator Loss: {:.4f}...".format(train_loss_d),
                          "Generator Loss: {:.4f}".format(train_loss_g))
                    
                
        show_generator_output(sess,show_n_images,z_inputs,img_channels,data_image_mode)

# %% [markdown]
# ### MNIST
# Test your GANs architecture on MNIST.  After 2 epochs, the GANs should be able to generate images that look like handwritten digits.  Make sure the loss of the generator is lower than the loss of the discriminator or close to 0.

# %%
batch_size = 64
z_dim = 100
learning_rate = 0.0002
beta1 = 0.5


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
epochs = 2

mnist_dataset = helper.Dataset('mnist', glob(os.path.join(data_dir, 'mnist/*.jpg')))
with tf.Graph().as_default():
    train(epochs, batch_size, z_dim, learning_rate, beta1, mnist_dataset.get_batches,
          mnist_dataset.shape, mnist_dataset.image_mode)
# Out:
# Epoch 1/2... Discriminator Loss: 0.5199... Generator Loss: 2.0482
# Epoch 1/2... Discriminator Loss: 1.8758... Generator Loss: 0.3338
# Epoch 1/2... Discriminator Loss: 1.3381... Generator Loss: 0.9582
# Epoch 1/2... Discriminator Loss: 1.4813... Generator Loss: 1.0178
# Epoch 1/2... Discriminator Loss: 1.4289... Generator Loss: 0.8840
# Epoch 1/2... Discriminator Loss: 1.5803... Generator Loss: 0.3861
# Epoch 1/2... Discriminator Loss: 1.2766... Generator Loss: 0.9037
# Epoch 1/2... Discriminator Loss: 1.3345... Generator Loss: 0.7591
# Epoch 1/2... Discriminator Loss: 1.1511... Generator Loss: 0.7132
# Epoch 1/2... Discriminator Loss: 1.0222... Generator Loss: 1.1430
# Epoch 1/2... Discriminator Loss: 1.0368... Generator Loss: 1.1358
# Epoch 1/2... Discriminator Loss: 1.0821... Generator Loss: 1.1216
# Epoch 1/2... Discriminator Loss: 1.0705... Generator Loss: 1.1747
# Epoch 1/2... Discriminator Loss: 1.1764... Generator Loss: 0.7518
# Epoch 1/2... Discriminator Loss: 1.2543... Generator Loss: 0.6426
# Epoch 1/2... Discriminator Loss: 1.1460... Generator Loss: 1.1164
# Epoch 1/2... Discriminator Loss: 1.1042... Generator Loss: 0.9816
# Epoch 1/2... Discriminator Loss: 1.1198... Generator Loss: 0.9644
# Epoch 1/2... Discriminator Loss: 1.2070... Generator Loss: 1.7399
# Epoch 1/2... Discriminator Loss: 1.0411... Generator Loss: 1.2242
# Epoch 1/2... Discriminator Loss: 1.1251... Generator Loss: 0.9532
# Epoch 1/2... Discriminator Loss: 1.4493... Generator Loss: 0.4752
# Epoch 1/2... Discriminator Loss: 1.1148... Generator Loss: 1.0698
# Epoch 1/2... Discriminator Loss: 1.0885... Generator Loss: 0.9032
# Epoch 1/2... Discriminator Loss: 1.1625... Generator Loss: 0.7655
# Epoch 1/2... Discriminator Loss: 1.1363... Generator Loss: 1.7237
# Epoch 1/2... Discriminator Loss: 1.1766... Generator Loss: 1.4663
# Epoch 1/2... Discriminator Loss: 1.0571... Generator Loss: 1.1270
# Epoch 1/2... Discriminator Loss: 1.1197... Generator Loss: 0.9981
# Epoch 1/2... Discriminator Loss: 1.1013... Generator Loss: 0.9040
# Epoch 1/2... Discriminator Loss: 1.0719... Generator Loss: 0.9082
# Epoch 1/2... Discriminator Loss: 1.0987... Generator Loss: 1.0807
# Epoch 1/2... Discriminator Loss: 1.0114... Generator Loss: 1.2764
# Epoch 1/2... Discriminator Loss: 1.2002... Generator Loss: 0.7147
# Epoch 1/2... Discriminator Loss: 0.9986... Generator Loss: 1.1471
# Epoch 1/2... Discriminator Loss: 1.0154... Generator Loss: 1.3584
# Epoch 1/2... Discriminator Loss: 1.1833... Generator Loss: 1.6488
# Epoch 1/2... Discriminator Loss: 1.3675... Generator Loss: 0.5282
# Epoch 1/2... Discriminator Loss: 1.0746... Generator Loss: 1.4555
# Epoch 1/2... Discriminator Loss: 1.0946... Generator Loss: 1.6425
# Epoch 1/2... Discriminator Loss: 0.8922... Generator Loss: 1.6877
# Epoch 1/2... Discriminator Loss: 1.1702... Generator Loss: 0.7035
# Epoch 1/2... Discriminator Loss: 1.2008... Generator Loss: 0.6550
# Epoch 1/2... Discriminator Loss: 0.9814... Generator Loss: 0.9217
# Epoch 1/2... Discriminator Loss: 1.2408... Generator Loss: 0.6492
# Epoch 1/2... Discriminator Loss: 0.9585... Generator Loss: 1.1009
# Epoch 2/2... Discriminator Loss: 1.0085... Generator Loss: 0.9303
# Epoch 2/2... Discriminator Loss: 1.0486... Generator Loss: 1.3602
# Epoch 2/2... Discriminator Loss: 1.6378... Generator Loss: 2.0681
# Epoch 2/2... Discriminator Loss: 1.0953... Generator Loss: 1.1101
# Epoch 2/2... Discriminator Loss: 0.9304... Generator Loss: 1.1565
# Epoch 2/2... Discriminator Loss: 1.9432... Generator Loss: 0.2894
# Epoch 2/2... Discriminator Loss: 1.0631... Generator Loss: 1.0070
# Epoch 2/2... Discriminator Loss: 0.8769... Generator Loss: 1.7945
# Epoch 2/2... Discriminator Loss: 0.9396... Generator Loss: 1.2108
# Epoch 2/2... Discriminator Loss: 1.2197... Generator Loss: 2.3565
# Epoch 2/2... Discriminator Loss: 1.0220... Generator Loss: 0.9315
# Epoch 2/2... Discriminator Loss: 1.1472... Generator Loss: 0.6834
# Epoch 2/2... Discriminator Loss: 1.0705... Generator Loss: 0.8182
# Epoch 2/2... Discriminator Loss: 1.1710... Generator Loss: 0.6542
# Epoch 2/2... Discriminator Loss: 0.8675... Generator Loss: 1.1876
# Epoch 2/2... Discriminator Loss: 1.4105... Generator Loss: 0.5007
# Epoch 2/2... Discriminator Loss: 1.9224... Generator Loss: 0.3300
# Epoch 2/2... Discriminator Loss: 1.1713... Generator Loss: 0.6749
# Epoch 2/2... Discriminator Loss: 0.9677... Generator Loss: 0.9905
# Epoch 2/2... Discriminator Loss: 1.0770... Generator Loss: 0.8348
# Epoch 2/2... Discriminator Loss: 1.1345... Generator Loss: 0.8438
# Epoch 2/2... Discriminator Loss: 0.9564... Generator Loss: 1.0460
# Epoch 2/2... Discriminator Loss: 1.1213... Generator Loss: 0.7215
# Epoch 2/2... Discriminator Loss: 0.8486... Generator Loss: 1.8826
# Epoch 2/2... Discriminator Loss: 1.1981... Generator Loss: 0.6500
# Epoch 2/2... Discriminator Loss: 1.1836... Generator Loss: 0.7041
# Epoch 2/2... Discriminator Loss: 0.9535... Generator Loss: 1.0018
# Epoch 2/2... Discriminator Loss: 0.8887... Generator Loss: 1.1566
# Epoch 2/2... Discriminator Loss: 0.9316... Generator Loss: 1.2200
# Epoch 2/2... Discriminator Loss: 1.1765... Generator Loss: 0.7748
# Epoch 2/2... Discriminator Loss: 0.9454... Generator Loss: 1.0525
# Epoch 2/2... Discriminator Loss: 0.9715... Generator Loss: 1.7520
# Epoch 2/2... Discriminator Loss: 0.9242... Generator Loss: 1.0155
# Epoch 2/2... Discriminator Loss: 1.5631... Generator Loss: 0.4803
# Epoch 2/2... Discriminator Loss: 0.8358... Generator Loss: 1.3817
# Epoch 2/2... Discriminator Loss: 0.8152... Generator Loss: 1.1709
# Epoch 2/2... Discriminator Loss: 0.9568... Generator Loss: 1.4125
# Epoch 2/2... Discriminator Loss: 0.8973... Generator Loss: 1.1898
# Epoch 2/2... Discriminator Loss: 0.9621... Generator Loss: 0.9834
# Epoch 2/2... Discriminator Loss: 1.0390... Generator Loss: 0.9142
# Epoch 2/2... Discriminator Loss: 1.0640... Generator Loss: 1.8373
# Epoch 2/2... Discriminator Loss: 0.8367... Generator Loss: 1.6686
# Epoch 2/2... Discriminator Loss: 0.9396... Generator Loss: 0.9430
# Epoch 2/2... Discriminator Loss: 0.9107... Generator Loss: 1.7349
# Epoch 2/2... Discriminator Loss: 1.0891... Generator Loss: 0.7562
# Epoch 2/2... Discriminator Loss: 1.3805... Generator Loss: 0.5793
# Epoch 2/2... Discriminator Loss: 0.6983... Generator Loss: 1.6134

# %% [markdown]
# ### CelebA
# Run your GANs on CelebA.  It will take around 20 minutes on the average GPU to run one epoch.  You can run the whole epoch or stop when it starts to generate realistic faces.

# %%
batch_size = 64
z_dim = 100
learning_rate = 0.0002
beta1 = 0.5


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
epochs = 1

celeba_dataset = helper.Dataset('celeba', glob(os.path.join(data_dir, 'img_align_celeba/*.jpg')))
with tf.Graph().as_default():
    train(epochs, batch_size, z_dim, learning_rate, beta1, celeba_dataset.get_batches,
          celeba_dataset.shape, celeba_dataset.image_mode)
# Out:
# Epoch 1/1... Discriminator Loss: 0.5479... Generator Loss: 2.4884
# Epoch 1/1... Discriminator Loss: 1.0353... Generator Loss: 0.8722
# Epoch 1/1... Discriminator Loss: 0.7348... Generator Loss: 1.8043
# Epoch 1/1... Discriminator Loss: 0.6837... Generator Loss: 2.3542
# Epoch 1/1... Discriminator Loss: 0.9754... Generator Loss: 1.0424
# Epoch 1/1... Discriminator Loss: 0.6451... Generator Loss: 3.0446
# Epoch 1/1... Discriminator Loss: 0.8178... Generator Loss: 1.1695
# Epoch 1/1... Discriminator Loss: 1.0598... Generator Loss: 4.8214
# Epoch 1/1... Discriminator Loss: 0.4049... Generator Loss: 3.3111
# Epoch 1/1... Discriminator Loss: 0.8066... Generator Loss: 2.1772
# Epoch 1/1... Discriminator Loss: 0.5000... Generator Loss: 2.8332
# Epoch 1/1... Discriminator Loss: 1.0003... Generator Loss: 0.9346
# Epoch 1/1... Discriminator Loss: 1.5355... Generator Loss: 0.4539
# Epoch 1/1... Discriminator Loss: 1.8741... Generator Loss: 0.3011
# Epoch 1/1... Discriminator Loss: 0.5937... Generator Loss: 3.0648
# Epoch 1/1... Discriminator Loss: 1.9666... Generator Loss: 0.2919
# Epoch 1/1... Discriminator Loss: 0.7453... Generator Loss: 1.3511
# Epoch 1/1... Discriminator Loss: 0.7500... Generator Loss: 1.6126
# Epoch 1/1... Discriminator Loss: 1.1881... Generator Loss: 0.8394
# Epoch 1/1... Discriminator Loss: 1.5091... Generator Loss: 3.8782
# Epoch 1/1... Discriminator Loss: 1.1090... Generator Loss: 0.7266
# Epoch 1/1... Discriminator Loss: 1.1188... Generator Loss: 1.6754
# Epoch 1/1... Discriminator Loss: 1.3536... Generator Loss: 0.5303
# Epoch 1/1... Discriminator Loss: 0.9146... Generator Loss: 1.1807
# Epoch 1/1... Discriminator Loss: 0.7240... Generator Loss: 1.3613
# Epoch 1/1... Discriminator Loss: 0.5167... Generator Loss: 3.2647
# Epoch 1/1... Discriminator Loss: 1.1255... Generator Loss: 3.2590
# Epoch 1/1... Discriminator Loss: 0.5865... Generator Loss: 1.7070
# Epoch 1/1... Discriminator Loss: 1.6154... Generator Loss: 0.3791
# Epoch 1/1... Discriminator Loss: 0.8440... Generator Loss: 1.0455
# Epoch 1/1... Discriminator Loss: 2.0031... Generator Loss: 0.3013
# Epoch 1/1... Discriminator Loss: 1.3105... Generator Loss: 0.5501
# Epoch 1/1... Discriminator Loss: 1.1912... Generator Loss: 3.3521
# Epoch 1/1... Discriminator Loss: 0.6618... Generator Loss: 1.5580
# Epoch 1/1... Discriminator Loss: 0.5820... Generator Loss: 2.7130
# Epoch 1/1... Discriminator Loss: 0.4677... Generator Loss: 2.7862
# Epoch 1/1... Discriminator Loss: 2.4211... Generator Loss: 0.1550
# Epoch 1/1... Discriminator Loss: 1.3507... Generator Loss: 0.5281
# Epoch 1/1... Discriminator Loss: 0.4973... Generator Loss: 2.3311
# Epoch 1/1... Discriminator Loss: 0.8283... Generator Loss: 1.1312
# Epoch 1/1... Discriminator Loss: 1.0958... Generator Loss: 0.7096
# Epoch 1/1... Discriminator Loss: 0.8744... Generator Loss: 3.5861
# Epoch 1/1... Discriminator Loss: 0.9523... Generator Loss: 3.1853
# Epoch 1/1... Discriminator Loss: 0.5756... Generator Loss: 2.4752
# Epoch 1/1... Discriminator Loss: 0.6300... Generator Loss: 1.6070
# Epoch 1/1... Discriminator Loss: 1.1827... Generator Loss: 4.5650
# Epoch 1/1... Discriminator Loss: 0.4515... Generator Loss: 3.4446
# Epoch 1/1... Discriminator Loss: 0.5763... Generator Loss: 2.2508
# Epoch 1/1... Discriminator Loss: 0.5762... Generator Loss: 2.7300
# Epoch 1/1... Discriminator Loss: 0.4696... Generator Loss: 3.2787
# Epoch 1/1... Discriminator Loss: 0.4374... Generator Loss: 3.5331
# Epoch 1/1... Discriminator Loss: 0.4407... Generator Loss: 3.2014
# Epoch 1/1... Discriminator Loss: 0.5724... Generator Loss: 1.8139
# Epoch 1/1... Discriminator Loss: 0.7184... Generator Loss: 1.4606
# Epoch 1/1... Discriminator Loss: 0.3921... Generator Loss: 3.4720
# Epoch 1/1... Discriminator Loss: 0.4371... Generator Loss: 3.9065
# Epoch 1/1... Discriminator Loss: 0.6842... Generator Loss: 4.3387
# Epoch 1/1... Discriminator Loss: 0.5879... Generator Loss: 1.6961
# Epoch 1/1... Discriminator Loss: 0.3818... Generator Loss: 3.8359
# Epoch 1/1... Discriminator Loss: 0.4561... Generator Loss: 2.8256
# Epoch 1/1... Discriminator Loss: 2.1405... Generator Loss: 0.4398
# Epoch 1/1... Discriminator Loss: 0.5151... Generator Loss: 2.2224
# Epoch 1/1... Discriminator Loss: 0.5368... Generator Loss: 4.3636
# Epoch 1/1... Discriminator Loss: 0.3840... Generator Loss: 4.7687
# Epoch 1/1... Discriminator Loss: 2.9362... Generator Loss: 0.1067
# Epoch 1/1... Discriminator Loss: 0.4501... Generator Loss: 3.3663
# Epoch 1/1... Discriminator Loss: 0.5025... Generator Loss: 2.1679
# Epoch 1/1... Discriminator Loss: 0.5714... Generator Loss: 1.7717
# Epoch 1/1... Discriminator Loss: 0.5403... Generator Loss: 4.7584
# Epoch 1/1... Discriminator Loss: 0.3696... Generator Loss: 4.3474
# Epoch 1/1... Discriminator Loss: 0.4468... Generator Loss: 3.9240
# Epoch 1/1... Discriminator Loss: 0.7117... Generator Loss: 1.9227
# Epoch 1/1... Discriminator Loss: 1.8047... Generator Loss: 0.3839
# Epoch 1/1... Discriminator Loss: 0.6130... Generator Loss: 2.1547
# Epoch 1/1... Discriminator Loss: 0.4943... Generator Loss: 4.2056
# Epoch 1/1... Discriminator Loss: 0.4332... Generator Loss: 2.7043
# Epoch 1/1... Discriminator Loss: 0.4661... Generator Loss: 3.1121
# Epoch 1/1... Discriminator Loss: 0.4839... Generator Loss: 2.3382
# Epoch 1/1... Discriminator Loss: 0.4425... Generator Loss: 4.0310
# Epoch 1/1... Discriminator Loss: 0.5440... Generator Loss: 1.9983
# Epoch 1/1... Discriminator Loss: 0.5050... Generator Loss: 2.0713
# Epoch 1/1... Discriminator Loss: 0.6599... Generator Loss: 1.4236
# Epoch 1/1... Discriminator Loss: 0.6069... Generator Loss: 2.0167
# Epoch 1/1... Discriminator Loss: 2.7277... Generator Loss: 0.1280
# Epoch 1/1... Discriminator Loss: 0.3621... Generator Loss: 4.3594
# Epoch 1/1... Discriminator Loss: 0.3919... Generator Loss: 5.0638
# Epoch 1/1... Discriminator Loss: 0.4890... Generator Loss: 2.2271
# Epoch 1/1... Discriminator Loss: 0.3735... Generator Loss: 3.9849
# Epoch 1/1... Discriminator Loss: 0.6405... Generator Loss: 1.5495
# Epoch 1/1... Discriminator Loss: 0.4989... Generator Loss: 2.7215
# Epoch 1/1... Discriminator Loss: 0.4966... Generator Loss: 2.2576
# Epoch 1/1... Discriminator Loss: 0.4387... Generator Loss: 2.7899
# Epoch 1/1... Discriminator Loss: 1.6944... Generator Loss: 0.4077
# Epoch 1/1... Discriminator Loss: 0.4255... Generator Loss: 3.2635
# Epoch 1/1... Discriminator Loss: 0.3963... Generator Loss: 4.3848
# Epoch 1/1... Discriminator Loss: 0.5941... Generator Loss: 1.6930
# Epoch 1/1... Discriminator Loss: 2.5744... Generator Loss: 0.1518
# Epoch 1/1... Discriminator Loss: 0.9152... Generator Loss: 2.8310
# Epoch 1/1... Discriminator Loss: 0.4819... Generator Loss: 3.3251
# Epoch 1/1... Discriminator Loss: 0.4384... Generator Loss: 2.9941
# Epoch 1/1... Discriminator Loss: 0.5242... Generator Loss: 3.8467
# Epoch 1/1... Discriminator Loss: 0.5277... Generator Loss: 2.0190
# Epoch 1/1... Discriminator Loss: 0.7941... Generator Loss: 1.5825
# Epoch 1/1... Discriminator Loss: 0.4155... Generator Loss: 3.1309
# Epoch 1/1... Discriminator Loss: 0.6320... Generator Loss: 1.7208
# Epoch 1/1... Discriminator Loss: 0.4823... Generator Loss: 2.3159
# Epoch 1/1... Discriminator Loss: 0.6078... Generator Loss: 2.2424
# Epoch 1/1... Discriminator Loss: 0.9538... Generator Loss: 1.2771
# Epoch 1/1... Discriminator Loss: 1.1039... Generator Loss: 0.7065
# Epoch 1/1... Discriminator Loss: 0.5843... Generator Loss: 3.9060
# Epoch 1/1... Discriminator Loss: 0.5355... Generator Loss: 3.0474
# Epoch 1/1... Discriminator Loss: 0.5442... Generator Loss: 2.0536
# Epoch 1/1... Discriminator Loss: 0.5979... Generator Loss: 1.8029
# Epoch 1/1... Discriminator Loss: 0.7162... Generator Loss: 1.4969
# Epoch 1/1... Discriminator Loss: 1.0181... Generator Loss: 0.8843
# Epoch 1/1... Discriminator Loss: 0.7701... Generator Loss: 1.2929
# Epoch 1/1... Discriminator Loss: 0.7028... Generator Loss: 2.3195
# Epoch 1/1... Discriminator Loss: 0.4571... Generator Loss: 2.7306
# Epoch 1/1... Discriminator Loss: 0.4963... Generator Loss: 2.5327
# Epoch 1/1... Discriminator Loss: 0.4557... Generator Loss: 2.7197
# Epoch 1/1... Discriminator Loss: 0.4973... Generator Loss: 2.7771
# Epoch 1/1... Discriminator Loss: 0.5617... Generator Loss: 1.9952
# Epoch 1/1... Discriminator Loss: 0.9614... Generator Loss: 0.9973
# Epoch 1/1... Discriminator Loss: 0.5470... Generator Loss: 3.7973
# Epoch 1/1... Discriminator Loss: 0.5395... Generator Loss: 3.4396
# Epoch 1/1... Discriminator Loss: 2.0505... Generator Loss: 2.9802
# Epoch 1/1... Discriminator Loss: 0.8438... Generator Loss: 1.2500
# Epoch 1/1... Discriminator Loss: 0.3794... Generator Loss: 4.4031
# Epoch 1/1... Discriminator Loss: 0.6540... Generator Loss: 2.3399
# Epoch 1/1... Discriminator Loss: 0.5789... Generator Loss: 1.8118
# Epoch 1/1... Discriminator Loss: 0.5376... Generator Loss: 1.9710
# Epoch 1/1... Discriminator Loss: 0.6876... Generator Loss: 1.6012
# Epoch 1/1... Discriminator Loss: 1.3802... Generator Loss: 3.1244
# Epoch 1/1... Discriminator Loss: 0.9084... Generator Loss: 1.1626
# Epoch 1/1... Discriminator Loss: 0.7473... Generator Loss: 2.0030
# Epoch 1/1... Discriminator Loss: 0.5258... Generator Loss: 3.4462
# Epoch 1/1... Discriminator Loss: 0.6630... Generator Loss: 1.9586
# Epoch 1/1... Discriminator Loss: 0.8847... Generator Loss: 1.0700
# Epoch 1/1... Discriminator Loss: 1.3739... Generator Loss: 0.5201
# Epoch 1/1... Discriminator Loss: 0.6750... Generator Loss: 1.4198
# Epoch 1/1... Discriminator Loss: 0.3889... Generator Loss: 3.7937
# Epoch 1/1... Discriminator Loss: 0.4727... Generator Loss: 2.3819
# Epoch 1/1... Discriminator Loss: 0.8374... Generator Loss: 1.1160
# Epoch 1/1... Discriminator Loss: 0.6832... Generator Loss: 1.4612
# Epoch 1/1... Discriminator Loss: 1.3165... Generator Loss: 0.5683
# Epoch 1/1... Discriminator Loss: 0.4287... Generator Loss: 3.5013
# Epoch 1/1... Discriminator Loss: 0.9720... Generator Loss: 0.9683
# Epoch 1/1... Discriminator Loss: 0.6918... Generator Loss: 1.3954
# Epoch 1/1... Discriminator Loss: 0.7382... Generator Loss: 1.5880
# Epoch 1/1... Discriminator Loss: 0.4806... Generator Loss: 2.4975
# Epoch 1/1... Discriminator Loss: 0.5055... Generator Loss: 2.4318
# Epoch 1/1... Discriminator Loss: 0.4746... Generator Loss: 2.5720
# Epoch 1/1... Discriminator Loss: 0.7239... Generator Loss: 1.3300
# Epoch 1/1... Discriminator Loss: 0.5238... Generator Loss: 3.0878
# Epoch 1/1... Discriminator Loss: 0.7153... Generator Loss: 1.4232
# Epoch 1/1... Discriminator Loss: 0.5484... Generator Loss: 2.0580
# Epoch 1/1... Discriminator Loss: 0.8447... Generator Loss: 1.1230
# Epoch 1/1... Discriminator Loss: 0.9463... Generator Loss: 3.1753

# %% [markdown]
# ### Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_face_generation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "helper.py" and "problem_unittests.py" files in your submission.
